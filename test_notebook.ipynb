# %% [markdown]
# # ECG Experiment
#
# Automatically generated ECG experiment notebook.

# %%
# Data loading and preprocessing
# TODO: Add code to load PTB-XL dataset

# %%
# Model training (ResNet)
# TODO: Add training code

# %%
# Model training (Transformer)
# TODO: Add training code

# %%
# Evaluation and per-class metrics
# TODO: Add evaluation code

# %%
# MLflow logging
# TODO: Add MLflow logging code

# %%
# Visualisation
# TODO: Add plots (e.g., matplotlib)
